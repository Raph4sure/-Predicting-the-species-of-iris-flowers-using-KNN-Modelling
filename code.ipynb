# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop("Id", axis=1, inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Exploring the data distribution of each variable

df.plot(kind='kde', subplots=True, layout=(2,2), figsize=(12,6))
plt.show()

# %%
# Identifying outliers in each variable

df.plot(kind='box', subplots=True, layout=(2,2), figsize=(12,6))
plt.show()

# %%
# Exploring the relationships between each pair of inputs and output

sns.pairplot(data=df, hue='Species')
plt.show()

# %%
# Segregating inputs and output

y = df['Species'] # Target Variable

X = df[['PetalLengthCm', 'SepalWidthCm', 'PetalWidthCm', 'SepalLengthCm']]  # Input Varaibles

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
X.head()
# Out:
#    PetalLengthCm  SepalWidthCm  PetalWidthCm  SepalLengthCm
# 0            1.4           3.5           0.2            5.1
# 1            1.4           3.0           0.2            4.9
# 2            1.3           3.2           0.2            4.7
# 3            1.5           3.1           0.2            4.6
# 4            1.4           3.6           0.2            5.0

# %%
# Splitting into train and test

# Imporitng libraries
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (112, 4) (112,)
# (38, 4) (38,)

# %%
# Applying the data preparation and transformmation on training data
